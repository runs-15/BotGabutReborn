# %%
import datetime
import pytz

d = datetime.datetime.now()
timezone = pytz.timezone("Asia/Jakarta")
d_aware = timezone.localize(d)
d_aware.strftime("%A")
# Out:
# 'Friday'

# %%
#mongoDB connection
from pymongo import MongoClient

# Provide the mongodb atlas url to connect python to mongodb using pymongo
CONNECTION_STRING = "mongodb+srv://runs:yahtadiy@botgabutcluster.14awb.mongodb.net/siswa?retryWrites=true&w=majority"
client = MongoClient(CONNECTION_STRING)

# %%
[i['server_id'] for i in client['servers']['server'].find()]
# Out:
# [850284530501812224]

# %%
import random
# Create the database for our example (we will use the same database throughout the tutorial
data = [i for i in client['siswa']['presensi'].find()]
sequence = random.sample(data, len(data))
sequence
# Out:
# [{'_id': ObjectId('61d81ec99e3dec2ad051c2da'),
#   'nis': 16446,
#   'password': 20060524,
#   'discord_id': 627138670234828800},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2c8'),
#   'nis': 16288,
#   'password': 20041118,
#   'discord_id': 462825721916686340},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2c1'),
#   'nis': 16453,
#   'password': 20041010,
#   'discord_id': 692749231089254500},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2b7'),
#   'nis': 16419,
#   'password': 20050801,
#   'discord_id': 692749231089254500},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2dd'),
#   'nis': 16425,
#   'password': 20051016,
#   'discord_id': 486171419256815600},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2d0'),
#   'nis': 16489,
#   'password': 20050415,
#   'discord_id': 438230172437577700},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2db'),
#   'nis': 16375,
#   'password': 20060724,
#   'discord_id': 452847764167065600},
#  {'_id': ObjectId('61d81ec99e3dec2ad051c2b8'),
#   'nis': 16128,
# ...

# %%
import inspect
attributes = inspect.getmembers(inspect, lambda a:not(inspect.isroutine(a)))
attr = dict([a for a in attributes if not(a[0].startswith('__') and a[0].endswith('__'))])
attr
# Out:
# {'ArgInfo': inspect.ArgInfo,
#  'ArgSpec': inspect.ArgSpec,
#  'Arguments': inspect.Arguments,
#  'Attribute': inspect.Attribute,
#  'BlockFinder': inspect.BlockFinder,
#  'BoundArguments': inspect.BoundArguments,
#  'CORO_CLOSED': 'CORO_CLOSED',
#  'CORO_CREATED': 'CORO_CREATED',
#  'CORO_RUNNING': 'CORO_RUNNING',
#  'CORO_SUSPENDED': 'CORO_SUSPENDED',
#  'CO_ASYNC_GENERATOR': 512,
#  'CO_COROUTINE': 128,
#  'CO_GENERATOR': 32,
#  'CO_ITERABLE_COROUTINE': 256,
#  'CO_NESTED': 16,
#  'CO_NEWLOCALS': 2,
#  'CO_NOFREE': 64,
#  'CO_OPTIMIZED': 1,
#  'CO_VARARGS': 4,
#  'CO_VARKEYWORDS': 8,
#  'ClassFoundException': inspect.ClassFoundException,
#  'ClosureVars': inspect.ClosureVars,
#  'EndOfBlock': inspect.EndOfBlock,
#  'FrameInfo': inspect.FrameInfo,
#  'FullArgSpec': inspect.FullArgSpec,
#  'GEN_CLOSED': 'GEN_CLOSED',
#  'GEN_CREATED': 'GEN_CREATED',
#  'GEN_RUNNING': 'GEN_RUNNING',
#  'GEN_SUSPENDED': 'GEN_SUSPENDED',
#  'OrderedDict': collections.OrderedDict,
# ...
